# %% [markdown]
# # Biblioteker
#
# - Tillegg til Python
# - Må importeres
# - Nyttige funksjoner som eliminerer en del koding fra skratch

# %% [markdown]
# ![image.png](attachment:82760aaf-3dc8-418e-9d92-b27256deea84.png)

# %% [markdown]
# # Standardbibliotek
# - Allerede tilgjengelig i Python, men må importeres
# - De viktigste:
#     - Math
#     - Random
#     - Counter (valgfritt)

# %% [markdown]
# # Math
# Eksempler på funksjoner vi kan bruke:
# - math.pi()
# - math.ceil(x) - *runder x oppover*
# - math.floor(x) - *runder x nedover*
# - math.sqrt(x) - *tar kvadratroten av x*
# - math.log(x) - *logaritmen av x*
# - math.cos(x), math.sin(x), math.tan(X) - *cos, sin og tan av x*
# - math.comb(n, k) - *velge k items fra n items uten repetisjon og orden*
# Fullstendig liste: https://docs.python.org/3/library/math.html

# %%
import math

x = 3.9 
y = 16

print(f"Hente ut 𝝅: {math.pi:.2f}")
print(f"Tall: {x}, avrundet oppover: {math.ceil(x)}")
print(f"Tall: {x}, avrundet nedover: {math.floor(x)}")
print(f"Kvadradroten av {y} = {math.sqrt(y)}")
print(f"Logaritmen av {y} = {math.log(y):.2f}")
print(f"cos({y}) = {math.cos(y):.2f}")
print(f"{math.comb(2, 1)}")
# Out:
# Hente ut 𝝅: 3.14
# Tall: 3.9, avrundet oppover: 4
# Tall: 3.9, avrundet nedover: 3
# Kvadradroten av 16 =  4.0
# Logaritmen av 16 = 2.77
# cos(16) = -0.96
# 2

# %% [markdown]
# # Random
#
# Innebygd modul for å lage tilfeldige tall. Ofte bruker vi randint() funksjonen.
#
# For mer omfattende dokumentasjon, se: https://docs.python.org/3/library/random.html

# %%
import random 

# Simulere et terningkast 
def roll_dice():
    return random.randint(1,6)
    
print(f"Kastet en terning og fikk {roll_dice()} \n\n")



# Lage en enkel AI mot AI -> Stein, papir, saks: 
choices = ["stein", "papir", "saks"]
ai1_choice, ai2_choice = choices[random.randint(0,2)], choices[random.randint(0,2)]
print(f"Spiller 1: {ai1_choice}, Spiller 2: {ai2_choice}")
# Out:
# Kastet en terning og fikk 1
#
#
# Spiller 1: saks, Spiller 2: saks

# %% [markdown]
# # Counter
# Tar inn en liste, string, tuple eller dict som input og outputer antallet av hvert element som en dictionary

# %%
from collections import Counter 

liste = ['x','y','z','x','x','x','y', 'z']
print(Counter(liste))

print()

streng = "INF100"
print(Counter(streng))
# Out:
# Counter({'x': 4, 'y': 2, 'z': 2})
#
# Counter({'0': 2, 'I': 1, 'N': 1, 'F': 1, '1': 1})

# %% [markdown]
# # Eksterne biblioteker
# - Laget av en tredjepart, må installeres lokalt (eller virtuelt)
# - De viktigste i kurset:
#     - Numpy
#     - Matplotlib (!!)
#     - Pandas (valgfritt)

# %% [markdown]
# # NumPy
# - Bibliotek for å jobbe med arrays
# - Samme formål som vanlige lister/arrays i Python, men mye raskere

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5, 6]) # eller: arr = np.arange(1, 7) 

print(f"Array = {arr}")
print()

print(f"Reshape {arr} fra 1D til 2D: {arr.reshape(2,3)}")
# Out:
# Array = [1 2 3 4 5 6]
#
# Reshape [1 2 3 4 5 6] fra 1D til 2D: [[1 2 3]
#  [4 5 6]]

# %%
print("Iterere over et NumPy-array")

for x in arr:
    print(x)
    
print()
print("Vi kan lage filter for arrayet:")
print("Setter alle verdier mindre enn 3 til å være 0")

arr[arr < 3] = 0

print(arr)
# Out:
# Iterere over et NumPy-array
# 1
# 2
# 3
# 4
# 5
# 6
#
# Vi kan lage filter for arrayet:
# Setter alle verdier mindre enn 3 til å være 0
# [0 0 3 4 5 6]

# %% [markdown]
# # Matplotlib
# - Low-level grafplottingsverktøy for Python
# - **OBS**: David lager alltid eksamensoppgave med plotting
#
# Tips: https://matplotlib.org/stable/gallery/index.html her finner dere mange eksempel på ulike plot

# %%
import matplotlib.pyplot as plt 
from math import sin, cos

xs = [n / 10 for n in range(101)]
ys_1 = [cos(x) for x in xs]
ys_2 = [-cos(x) for x in xs]

plt.plot(xs, ys_1, "-.b") # plotter grafen til xs og ys_1 med mønsteret: -. i fargen blå 
plt.plot(xs, ys_2, "-r") # plotter grafen til xs og ys_2 med mønsteret: - (vanlig linje) i fargen rød 

plt.title("Àndrès hjemmesnekra Matplotlib kunst") # setter hovedtittel på plottet

plt.xlabel("x") # navngir x-akse
plt.ylabel("y") # navngir y-akse

plt.legend(["kul graf", "kul graf motsatt vei"]) # Lager boks som viser hva grafene viser til. PS: husk rekkefølge hvis du har flere grafer
plt.savefig("kulgraf.png")
#plt.show() # Viser grafen i interaktivt vindu

# %% [markdown]
# ![image.png](attachment:5b58e40b-9b6b-4275-8003-fe39681a8db6.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

# PLOT 1 
x = np.array(["A", "B", "C", "D", "E", "F"])
y = np.array([0, 0, 0, 0, 0, 20])

plt.subplot(1, 3, 1)
plt.title("INF100 karakterer før kræsjkurs")
plt.bar(x,y) # tilsvarende plt.plot() bare med bar() for å få stolpediagram

# PLOT 2
y = np.array([0, 0, 0, 3, 7, 10])

plt.subplot(1, 3, 3)
plt.title("INF100 karakterer etter kræsjkurs")
plt.bar(x,y) # tilsvarende plt.plot() bare med bar() for å få stolpediagram

plt.savefig("karakterfordeling.png")

#plt.show()

# %% [markdown]
# ![image.png](attachment:fae21173-b945-4db7-abc7-3ea96b7866d8.png)

# %% [markdown]
# # Pandas
# - Bibliotek for å jobbe med datasett
# - Analysere, rense, utforske og manipulere data
# - I INF100 bruker vi det hovedsaklig med CSV-filer
#     - Valgfritt om man bruker csv-biblioteket eller pandas

# %%
import pandas as pd

my_dataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'prices': [300000, 790000, 233000]
}

var = pd.DataFrame(my_dataset)

print(var)
# Out:
#     cars  prices
# 0    BMW  300000
# 1  Volvo  790000
# 2   Ford  233000

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df) # Pandas returnerer de 5 første og de 5 siste radene by default i større datasett 

# print(df.to_string()) # .to_string() vil gi oss hele datasettet
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# # Kildeføring
#
# ![image.png](attachment:12086789-5e2e-4abf-a0be-c60d9649f56f.png)

# %% [markdown]
# # Eksamenstips
# - Ikke kast bort tid på kortsvarsoppgavene
# - Bruk god tid på å forstå hva du skal gjøre på langssvarsoppgavene
# - Hvis du ikke vet akkurat hvordan du går frem for å kode funksjonalitet, skriv en kommentar der du forklarer hva du ville gjort
# - Test koden din i editor (VScode) og deretter lim inn i Inspera

# %% [markdown]
# # Kortsvarsoppgaver
# - Kan dobbeltsjekkes ved å lime inn kodealternativene i VSCode, verifiser at du får samme svar
# - På oppgavene der man skal bestemme datatyper kan man bruke type()-funksjonen til å verifisere typene
#
# **NB: Ikke bruk all tiden din på å dobbeltsjekke at du har gjort rett på kortsvarsoppgavene**

# %%
a = "Hello"
b = 1.3
c = 7
d = True

print(f"Datatypen til {a} = {type(a)}")
print(f"Datatypen til: {a*c} = {type(a*c)}")
print(f"Datatypen til: {len(a)} = {type(len(a))}")
print(f"Datatypen til {[d]} = {type([d])}")
print(f"Datatypen til {a.lower() == 'hello'} = {type(a.lower() == 'hello')}")
# Out:
# Datatypen til Hello = <class 'str'>
# Datatypen til: HelloHelloHelloHelloHelloHelloHello = <class 'str'>
# Datatypen til: 5 = <class 'int'>
# Datatypen til [True] = <class 'list'>
# Datatypen til True = <class 'bool'>

# %% [markdown]
# # Sensorveiledning
# Sensorveiledning fra en langssvarsoppgave V21
#
# ![image.png](attachment:b0b53a9f-1a0f-49cd-9326-55122d326f0f.png)

# %% [markdown]
# # Eksamensoppgaver
#
# Eksamen V21 - Oppgave 17 (matplotlib/csv)
#
# Eksamen V20 - Oppgave 15 (matplotlib)
